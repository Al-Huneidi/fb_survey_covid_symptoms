# %% [markdown]
# ## US Facebook Survey Results

# %%
# Import dependencies to import csv and create a dataframe.
from path import Path
import pandas as pd

# %%
# Read in the data and create dataframe.
data = Path('/Users/julieal-huneidi/Desktop/covid_challenge/Resources/overall-state.csv')
df = pd.read_csv(data)

# Take an overall look at the data included in the data set
# to see what is included in the columns.
df.head(5)
# Out:
#          date state_code  gender age_bucket    n    weight_sums  pct_cli  \
# 0  2020-04-06         ak  female      18-34  119   78755.310877   0.8772
# 1  2020-04-06         ak  female      35-54   95   63666.933392   3.2258
# 2  2020-04-06         ak  female        55+   51   52710.069695   0.0000
# 3  2020-04-06         al  female      18-34  478  480481.152573   0.8547
# 4  2020-04-06         al  female      35-54  482  557081.407562   1.4706
#
#    pct_ili  pct_cli_anosmia_ageusia  pct_hh_cli  ...  pct_diabetes_weighted  \
# 0   0.8772                   2.6316      0.8403  ...                 3.1304
# 1   3.2258                   3.2258      3.1579  ...                 9.7745
# 2   0.0000                   1.9608      0.0000  ...                 6.9947
# 3   1.0684                   2.1368      1.6771  ...                 3.1854
# 4   1.6807                   2.3109      2.2869  ...                12.1389
#
#    pct_cancer_weighted  pct_heart_disease_weighted  \
# ...

# %%
# Find out how many rows are in the dataset.
df.shape
# Out:
# (83404, 104)

# %%
# Find out the data types of the data in the columns.
df.dtypes
# Out:
# date                                                         object
# state_code                                                   object
# gender                                                       object
# age_bucket                                                   object
# n                                                             int64
# weight_sums                                                 float64
# pct_cli                                                     float64
# pct_ili                                                     float64
# pct_cli_anosmia_ageusia                                     float64
# pct_hh_cli                                                  float64
# pct_cmnty_cli                                               float64
# pct_hh_fever                                                float64
# pct_hh_sore_throat                                          float64
# pct_hh_cough                                                float64
# ...

# %%
# Check to see the last date of survey data in dataset.
df.tail(5)
# Out:
#              date state_code   gender age_bucket     n   weight_sums  pct_cli  \
# 83399  2020-09-11         vt  overall    overall   140  4.625695e+05   0.0000
# 83400  2020-09-11         wa  overall    overall  1027  5.065740e+06   0.2930
# 83401  2020-09-11         wi  overall    overall   893  3.906209e+06   0.4510
# 83402  2020-09-11         wv  overall    overall   298  1.142661e+06   1.3699
# 83403  2020-09-11         wy  overall    overall   122  3.607830e+05   0.0000
#
#        pct_ili  pct_cli_anosmia_ageusia  pct_hh_cli  ...  \
# 83399   0.0000                   0.0000      0.0000  ...
# 83400   0.2930                   1.2695      0.6849  ...
# 83401   0.4510                   1.2401      1.0124  ...
# 83402   1.0274                   1.7123      1.3468  ...
# 83403   0.0000                   2.4590      0.8264  ...
#
#        pct_diabetes_weighted  pct_cancer_weighted  pct_heart_disease_weighted  \
# ...
